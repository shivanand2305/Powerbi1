# %% [markdown]
# ### Assignment-1

# %% [markdown]
# ### Power desktop starts page

# %% [markdown]
# ![home_start%20page.png](attachment:home_start%20page.png)

# %% [markdown]
# ### Report view

# %% [markdown]
# ![report_view.png](attachment:report_view.png)

# %% [markdown]
# ### Data view

# %% [markdown]
# ![data%20view.png](attachment:data%20view.png)

# %% [markdown]
# ### Model view

# %% [markdown]
# ![model%20view.png](attachment:model%20view.png)

# %% [markdown]
# ### power query editor

# %% [markdown]
# ![power%20query%20editor.png](attachment:power%20query%20editor.png)

# %% [markdown]
# ### Advance Editor

# %% [markdown]
# ![advance%20editor.png](attachment:advance%20editor.png)
